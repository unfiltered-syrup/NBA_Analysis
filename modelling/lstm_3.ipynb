# %% [markdown]
# # Baseline Model

# %% [markdown]
# ## Importing libraries and data

# %%
import pandas as pd
import numpy as np
from math import pi
import os
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, Markdown
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from itertools import product

# %%
#navigating to properfile
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/MyDrive/Colab Notebooks/deeplearning/project/nba_game_data' #MODIFY THIS PATH FOR YOUR OWN DEVICE
os.chdir(path)
os.path.abspath(os.getcwd())
# Out:
# Mounted at /content/drive
# '/content/drive/MyDrive/Colab Notebooks/deeplearning/project/nba_game_data'

# %%
games_details = pd.read_csv('games_details.csv')
players = pd.read_csv('players.csv')
teams = pd.read_csv('teams.csv')
ranking = pd.read_csv('ranking.csv')
games  = pd.read_csv('games_with_sentiment.csv')
# Out:
# <ipython-input-3-2d7ab1a0b950>:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   games_details = pd.read_csv('games_details.csv')

# %%
path = '/content/drive/MyDrive/Colab Notebooks/deeplearning/project/results' #MODIFY THIS PATH FOR YOUR OWN DEVICE
os.chdir(path)
os.path.abspath(os.getcwd())
# Out:
# '/content/drive/MyDrive/Colab Notebooks/deeplearning/project/results'

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from keras import optimizers
from keras.models import Sequential, load_model
from keras.layers import Dense,Activation, LSTM, Dropout, TimeDistributed, Flatten, BatchNormalization
# from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint

from sklearn.utils import class_weight
from math import sqrt
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Data Exploration

# %%
games_details.shape
# Out:
# (668628, 29)

# %%
games_details.head()
# Out:
#     GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0  22200477  1610612759               SAS  San Antonio    1629641
# 1  22200477  1610612759               SAS  San Antonio    1631110
# 2  22200477  1610612759               SAS  San Antonio    1627751
# 3  22200477  1610612759               SAS  San Antonio    1630170
# 4  22200477  1610612759               SAS  San Antonio    1630200
#
#       PLAYER_NAME NICKNAME START_POSITION COMMENT    MIN  ...  OREB  DREB  \
# 0  Romeo Langford    Romeo              F     NaN  18:06  ...   1.0   1.0
# 1   Jeremy Sochan   Jeremy              F     NaN  31:01  ...   6.0   3.0
# 2    Jakob Poeltl    Jakob              C     NaN  21:42  ...   1.0   3.0
# 3   Devin Vassell    Devin              G     NaN  30:20  ...   0.0   9.0
# 4       Tre Jones      Tre              G     NaN  27:44  ...   0.0   2.0
#
#    REB  AST  STL  BLK   TO   PF   PTS  PLUS_MINUS
# 0  2.0  0.0  1.0  0.0  2.0  5.0   2.0        -2.0
# 1  9.0  6.0  1.0  0.0  2.0  1.0  23.0       -14.0
# 2  4.0  1.0  1.0  0.0  2.0  4.0  13.0        -4.0
# 3  9.0  5.0  3.0  0.0  2.0  1.0  10.0       -18.0
# 4  2.0  3.0  0.0  0.0  2.0  2.0  19.0         0.0
#
# [5 rows x 29 columns]

# %%
players.shape
# Out:
# (7228, 4)

# %%
players.head()
# Out:
#         PLAYER_NAME     TEAM_ID  PLAYER_ID  SEASON
# 0     Royce O'Neale  1610612762    1626220    2019
# 1  Bojan Bogdanovic  1610612762     202711    2019
# 2       Rudy Gobert  1610612762     203497    2019
# 3  Donovan Mitchell  1610612762    1628378    2019
# 4       Mike Conley  1610612762     201144    2019

# %%
teams.shape
# Out:
# (30, 14)

# %%
teams.head(30)
# Out:
#     LEAGUE_ID     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION       NICKNAME  \
# 0           0  1610612737      1949      2019          ATL          Hawks
# 1           0  1610612738      1946      2019          BOS        Celtics
# 2           0  1610612740      2002      2019          NOP       Pelicans
# 3           0  1610612741      1966      2019          CHI          Bulls
# 4           0  1610612742      1980      2019          DAL      Mavericks
# 5           0  1610612743      1976      2019          DEN        Nuggets
# 6           0  1610612745      1967      2019          HOU        Rockets
# 7           0  1610612746      1970      2019          LAC       Clippers
# 8           0  1610612747      1948      2019          LAL         Lakers
# 9           0  1610612748      1988      2019          MIA           Heat
# 10          0  1610612749      1968      2019          MIL          Bucks
# 11          0  1610612750      1989      2019          MIN   Timberwolves
# 12          0  1610612751      1976      2019          BKN           Nets
# 13          0  1610612752      1946      2019          NYK         Knicks
# 14          0  1610612753      1989      2019          ORL          Magic
# 15          0  1610612754      1976      2019          IND         Pacers
# 16          0  1610612755      1949      2019          PHI          76ers
# 17          0  1610612756      1968      2019          PHX           Suns
# 18          0  1610612757      1970      2019          POR  Trail Blazers
# 19          0  1610612758      1948      2019          SAC          Kings
# 20          0  1610612759      1976      2019          SAS          Spurs
# 21          0  1610612760      1967      2019          OKC        Thunder
# 22          0  1610612761      1995      2019          TOR        Raptors
# 23          0  1610612762      1974      2019          UTA           Jazz
# 24          0  1610612763      1995      2019          MEM      Grizzlies
# 25          0  1610612764      1961      2019          WAS        Wizards
# 26          0  1610612765      1948      2019          DET        Pistons
# 27          0  1610612766      1988      2019          CHA        Hornets
# 28          0  1610612739      1970      2019          CLE      Cavaliers
# 29          0  1610612744      1946      2019          GSW       Warriors
#
#     YEARFOUNDED           CITY                       ARENA  ARENACAPACITY  \
# 0          1949        Atlanta            State Farm Arena        18729.0
# 1          1946         Boston                   TD Garden        18624.0
# 2          2002    New Orleans        Smoothie King Center            NaN
# 3          1966        Chicago               United Center        21711.0
# 4          1980         Dallas    American Airlines Center        19200.0
# 5          1976         Denver                Pepsi Center        19099.0
# 6          1967        Houston               Toyota Center        18104.0
# 7          1970    Los Angeles              Staples Center        19060.0
# 8          1948    Los Angeles              Staples Center        19060.0
# 9          1988          Miami      AmericanAirlines Arena        19600.0
# 10         1968      Milwaukee                Fiserv Forum        17500.0
# 11         1989      Minnesota               Target Center        19356.0
# 12         1976       Brooklyn             Barclays Center            NaN
# 13         1946       New York       Madison Square Garden        19763.0
# 14         1989        Orlando                Amway Center            0.0
# 15         1976        Indiana     Bankers Life Fieldhouse        18345.0
# 16         1949   Philadelphia          Wells Fargo Center            NaN
# 17         1968        Phoenix  Talking Stick Resort Arena            NaN
# 18         1970       Portland                 Moda Center        19980.0
# 19         1948     Sacramento             Golden 1 Center        17500.0
# 20         1976    San Antonio                 AT&T Center        18694.0
# 21         1967  Oklahoma City     Chesapeake Energy Arena        19163.0
# 22         1995        Toronto            Scotiabank Arena        19800.0
# 23         1974           Utah     Vivint Smart Home Arena        20148.0
# 24         1995        Memphis                  FedExForum        18119.0
# 25         1961     Washington           Capital One Arena        20647.0
# 26         1948        Detroit        Little Caesars Arena        21000.0
# 27         1988      Charlotte             Spectrum Center        19026.0
# 28         1970      Cleveland         Quicken Loans Arena        20562.0
# 29         1946   Golden State                Chase Center        19596.0
#
#                                   OWNER   GENERALMANAGER         HEADCOACH  \
# 0                          Tony Ressler   Travis Schlenk      Lloyd Pierce
# 1                         Wyc Grousbeck      Danny Ainge      Brad Stevens
# 2                            Tom Benson   Trajan Langdon      Alvin Gentry
# 3                       Jerry Reinsdorf       Gar Forman        Jim Boylen
# 4                            Mark Cuban    Donnie Nelson     Rick Carlisle
# 5                          Stan Kroenke     Tim Connelly    Michael Malone
# 6                       Tilman Fertitta      Daryl Morey     Mike D'Antoni
# 7                         Steve Ballmer   Michael Winger        Doc Rivers
# 8               Jerry Buss Family Trust      Rob Pelinka       Frank Vogel
# 9                          Micky Arison        Pat Riley    Erik Spoelstra
# 10            Wesley Edens & Marc Lasry        Jon Horst  Mike Budenholzer
# 11                          Glen Taylor     Scott Layden     Ryan Saunders
# 12                             Joe Tsai       Sean Marks    Kenny Atkinson
# 13            Cablevision (James Dolan)      Steve Mills     David Fizdale
# 14                           Rick DeVos     John Hammond    Steve Clifford
# 15                           Herb Simon  Kevin Pritchard     Nate McMillan
# 16                        Joshua Harris      Elton Brand       Brett Brown
# 17                        Robert Sarver      James Jones    Monty Williams
# 18                           Paul Allen      Neil Olshey      Terry Stotts
# 19                       Vivek Ranadive      Vlade Divac       Luke Walton
# 20                           Peter Holt     Brian Wright    Gregg Popovich
# 21                         Clay Bennett       Sam Presti     Billy Donovan
# 22  Maple Leaf Sports and Entertainment      Masai Ujiri        Nick Nurse
# 23                          Greg Miller   Dennis Lindsey       Quin Snyder
# 24                          Robert Pera     Zach Kleiman    Taylor Jenkins
# 25                          Ted Leonsis   Tommy Sheppard      Scott Brooks
# 26                            Tom Gores     Ed Stefanski       Dwane Casey
# 27                       Michael Jordan    Mitch Kupchak     James Borrego
# 28                          Dan Gilbert      Koby Altman      John Beilein
# 29                            Joe Lacob        Bob Myers        Steve Kerr
#
#                    DLEAGUEAFFILIATION
# 0                       Erie Bayhawks
# 1                     Maine Red Claws
# 2                        No Affiliate
# 3                    Windy City Bulls
# 4                       Texas Legends
# 5                        No Affiliate
# 6            Rio Grande Valley Vipers
# 7   Agua Caliente Clippers of Ontario
# 8                    South Bay Lakers
# 9                Sioux Falls Skyforce
# 10                     Wisconsin Herd
# 11                        Iowa Wolves
# 12                   Long Island Nets
# 13                 Westchester Knicks
# 14                     Lakeland Magic
# 15                Fort Wayne Mad Ants
# 16                Delaware Blue Coats
# 17              Northern Arizona Suns
# 18                       No Affiliate
# 19                     Stockton Kings
# 20                       Austin Spurs
# 21                 Oklahoma City Blue
# 22                        Raptors 905
# 23               Salt Lake City Stars
# 24                     Memphis Hustle
# 25                 Capital City Go-Go
# 26                 Grand Rapids Drive
# 27                   Greensboro Swarm
# 28                      Canton Charge
# 29                Santa Cruz Warriors

# %%
ranking.shape
# Out:
# (210342, 13)

# %%
ranking.head()
# Out:
#       TEAM_ID  LEAGUE_ID  SEASON_ID STANDINGSDATE CONFERENCE         TEAM   G  \
# 0  1610612743          0      22022    2022-12-22       West       Denver  30
# 1  1610612763          0      22022    2022-12-22       West      Memphis  30
# 2  1610612740          0      22022    2022-12-22       West  New Orleans  31
# 3  1610612756          0      22022    2022-12-22       West      Phoenix  32
# 4  1610612746          0      22022    2022-12-22       West  LA Clippers  33
#
#     W   L  W_PCT HOME_RECORD ROAD_RECORD  RETURNTOPLAY
# 0  19  11  0.633        10-3         9-8           NaN
# 1  19  11  0.633        13-2         6-9           NaN
# 2  19  12  0.613        13-4         6-8           NaN
# 3  19  13  0.594        14-4         5-9           NaN
# 4  19  14  0.576        11-7         8-7           NaN

# %%
ranking['STANDINGSDATE'].unique
# Out:
# <bound method Series.unique of 0         2022-12-22
# 1         2022-12-22
# 2         2022-12-22
# 3         2022-12-22
# 4         2022-12-22
#              ...
# 210337    2014-09-01
# 210338    2014-09-01
# 210339    2014-09-01
# 210340    2014-09-01
# 210341    2014-09-01
# Name: STANDINGSDATE, Length: 210342, dtype: object>

# %%
ranking.loc[ranking['STANDINGSDATE'].str[0:4] == '2022'].loc[ranking['TEAM_ID'] == 1610612743].sort_values(by=['STANDINGSDATE'],ascending=True,)
# Out:
#          TEAM_ID  LEAGUE_ID  SEASON_ID STANDINGSDATE CONFERENCE    TEAM   G  \
# 9604  1610612743          0      22021    2022-01-01       West  Denver  34
# 9589  1610612743          0      22021    2022-01-02       West  Denver  34
# 9575  1610612743          0      22021    2022-01-03       West  Denver  35
# 9560  1610612743          0      22021    2022-01-04       West  Denver  35
# 9547  1610612743          0      22021    2022-01-05       West  Denver  36
# ...          ...        ...        ...           ...        ...     ...  ..
# 61    1610612743          0      22022    2022-12-18       West  Denver  29
# 46    1610612743          0      22022    2022-12-19       West  Denver  29
# 30    1610612743          0      22022    2022-12-20       West  Denver  30
# 15    1610612743          0      22022    2022-12-21       West  Denver  30
# 0     1610612743          0      22022    2022-12-22       West  Denver  30
#
#        W   L  W_PCT HOME_RECORD ROAD_RECORD  RETURNTOPLAY
# 9604  18  16  0.529         8-6       10-10           NaN
# 9589  18  16  0.529         8-6       10-10           NaN
# 9575  18  17  0.514         8-6       10-11           NaN
# 9560  18  17  0.514         8-6       10-11           NaN
# 9547  18  18  0.500         8-7       10-11           NaN
# ...   ..  ..    ...         ...         ...           ...
# 61    18  11  0.621         9-3         9-8           NaN
# 46    18  11  0.621         9-3         9-8           NaN
# 30    19  11  0.633        10-3         9-8           NaN
# 15    19  11  0.633        10-3         9-8           NaN
# 0     19  11  0.633        10-3         9-8           NaN
#
# [356 rows x 13 columns]

# %%
games.shape
# Out:
# (26651, 28)

# %%
list(games.columns)
# Out:
# ['GAME_DATE_EST',
#  'GAME_ID',
#  'HOME_TEAM_ID',
#  'VISITOR_TEAM_ID',
#  'SEASON',
#  'PTS_home',
#  'FG_PCT_home',
#  'FT_PCT_home',
#  'FG3_PCT_home',
#  'AST_home',
#  'REB_home',
#  'TEAM_ID_away',
#  'PTS_away',
#  'FG_PCT_away',
#  'FT_PCT_away',
#  'FG3_PCT_away',
#  'AST_away',
#  'REB_away',
#  'HOME_TEAM_WINS',
#  'HOME_TEAM_NAME',
#  'VISITOR_TEAM_NAME',
#  'year_month',
#  'negative %_x',
#  'neutral %_x',
#  'positive %_x',
#  'negative %_y',
#  'neutral %_y',
#  'positive %_y']

# %%
games
# Out:
#       GAME_DATE_EST   GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_ID  SEASON  \
# 0        2022-12-22  22200477    1610612740       1610612759    2022
# 1        2022-12-22  22200478    1610612762       1610612764    2022
# 2        2022-12-21  22200466    1610612739       1610612749    2022
# 3        2022-12-21  22200467    1610612755       1610612765    2022
# 4        2022-12-21  22200468    1610612737       1610612741    2022
# ...             ...       ...           ...              ...     ...
# 26646    2014-10-06  11400007    1610612737       1610612740    2014
# 26647    2014-10-06  11400004    1610612741       1610612764    2014
# 26648    2014-10-06  11400005    1610612747       1610612743    2014
# 26649    2014-10-05  11400002    1610612761       1610612758    2014
# 26650    2014-10-04  11400001    1610612748       1610612740    2014
#
#        PTS_home  FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  ...  \
# 0         126.0        0.484        0.926         0.382      25.0  ...
# 1         120.0        0.488        0.952         0.457      16.0  ...
# 2         114.0        0.482        0.786         0.313      22.0  ...
# 3         113.0        0.441        0.909         0.297      27.0  ...
# 4         108.0        0.429        1.000         0.378      22.0  ...
# ...         ...          ...          ...           ...       ...  ...
# 26646      93.0        0.419        0.821         0.421      24.0  ...
# 26647      81.0        0.338        0.719         0.381      18.0  ...
# 26648      98.0        0.448        0.682         0.500      29.0  ...
# 26649      99.0        0.440        0.771         0.333      21.0  ...
# 26650      86.0        0.431        0.679         0.333      18.0  ...
#
#        HOME_TEAM_WINS       HOME_TEAM_NAME    VISITOR_TEAM_NAME  year_month  \
# 0                   1  New OrleansPelicans     San AntonioSpurs     2022-12
# 1                   1             UtahJazz    WashingtonWizards     2022-12
# 2                   1   ClevelandCavaliers       MilwaukeeBucks     2022-12
# 3                   1    Philadelphia76ers       DetroitPistons     2022-12
# 4                   0         AtlantaHawks         ChicagoBulls     2022-12
# ...               ...                  ...                  ...         ...
# 26646               1         AtlantaHawks  New OrleansPelicans     2014-10
# 26647               0         ChicagoBulls    WashingtonWizards     2014-10
# 26648               1    Los AngelesLakers        DenverNuggets     2014-10
# 26649               1       TorontoRaptors      SacramentoKings     2014-10
# 26650               0            MiamiHeat  New OrleansPelicans     2014-10
#
#        negative %_x  neutral %_x  positive %_x  negative %_y  neutral %_y  \
# 0         13.760926    53.310051     32.929024      13.85407    53.055657
# 1         13.760926    53.310051     32.929024      13.85407    53.055657
# 2         13.760926    53.310051     32.929024      13.85407    53.055657
# 3         13.760926    53.310051     32.929024      13.85407    53.055657
# 4         13.760926    53.310051     32.929024      13.85407    53.055657
# ...             ...          ...           ...           ...          ...
# 26646     13.760926    53.310051     32.929024      13.85407    53.055657
# 26647     13.760926    53.310051     32.929024      13.85407    53.055657
# 26648     13.760926    53.310051     32.929024      13.85407    53.055657
# 26649     13.760926    53.310051     32.929024      13.85407    53.055657
# 26650     13.760926    53.310051     32.929024      13.85407    53.055657
#
#       positive %_y
# 0        33.090273
# 1        33.090273
# 2        33.090273
# 3        33.090273
# 4        33.090273
# ...            ...
# 26646    33.090273
# 26647    33.090273
# 26648    33.090273
# 26649    33.090273
# 26650    33.090273
#
# [26651 rows x 28 columns]

# %% [markdown]
# ## Data Preparation

# %%
# selected_features = list(games.columns)
# to_drop = ['GAME_STATUS_TEXT','TEAM_ID_home']
# for var in to_drop:
#   selected_features.remove(var)

# %%
# games = games[selected_features]

# %%
games.head()
# Out:
#   GAME_DATE_EST   GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_ID  SEASON  PTS_home  \
# 0    2022-12-22  22200477    1610612740       1610612759    2022     126.0
# 1    2022-12-22  22200478    1610612762       1610612764    2022     120.0
# 2    2022-12-21  22200466    1610612739       1610612749    2022     114.0
# 3    2022-12-21  22200467    1610612755       1610612765    2022     113.0
# 4    2022-12-21  22200468    1610612737       1610612741    2022     108.0
#
#    FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  ...  HOME_TEAM_WINS  \
# 0        0.484        0.926         0.382      25.0  ...               1
# 1        0.488        0.952         0.457      16.0  ...               1
# 2        0.482        0.786         0.313      22.0  ...               1
# 3        0.441        0.909         0.297      27.0  ...               1
# 4        0.429        1.000         0.378      22.0  ...               0
#
#         HOME_TEAM_NAME  VISITOR_TEAM_NAME  year_month  negative %_x  \
# 0  New OrleansPelicans   San AntonioSpurs     2022-12     13.760926
# 1             UtahJazz  WashingtonWizards     2022-12     13.760926
# 2   ClevelandCavaliers     MilwaukeeBucks     2022-12     13.760926
# 3    Philadelphia76ers     DetroitPistons     2022-12     13.760926
# 4         AtlantaHawks       ChicagoBulls     2022-12     13.760926
#
#    neutral %_x  positive %_x  negative %_y  neutral %_y positive %_y
# 0    53.310051     32.929024      13.85407    53.055657    33.090273
# 1    53.310051     32.929024      13.85407    53.055657    33.090273
# 2    53.310051     32.929024      13.85407    53.055657    33.090273
# 3    53.310051     32.929024      13.85407    53.055657    33.090273
# 4    53.310051     32.929024      13.85407    53.055657    33.090273
#
# [5 rows x 28 columns]

# %%
games.loc[((games["HOME_TEAM_ID"] == 1610612748) | (games["VISITOR_TEAM_ID"] == 1610612748))].loc[games['SEASON'] == 2021]
# Out:
#      GAME_DATE_EST   GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_ID  SEASON  PTS_home  \
# 548     2022-05-29  42100307    1610612748       1610612738    2021      96.0
# 549     2022-05-27  42100306    1610612738       1610612748    2021     103.0
# 551     2022-05-25  42100305    1610612748       1610612738    2021      80.0
# 553     2022-05-23  42100304    1610612738       1610612748    2021     102.0
# 555     2022-05-21  42100303    1610612738       1610612748    2021     103.0
# ...            ...       ...           ...              ...     ...       ...
# 1873    2021-10-14  12100055    1610612737       1610612748    2021     127.0
# 1887    2021-10-11  12100040    1610612748       1610612766    2021     104.0
# 1904    2021-10-08  12100029    1610612759       1610612748    2021     105.0
# 1909    2021-10-07  12100024    1610612745       1610612748    2021     106.0
# 1923    2021-10-04  12100004    1610612748       1610612737    2021     125.0
#
#       FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  ...  HOME_TEAM_WINS  \
# 548         0.420        0.667         0.200      16.0  ...               0
# 549         0.444        0.903         0.333      22.0  ...               0
# 551         0.319        0.929         0.156      14.0  ...               0
# 553         0.397        0.842         0.235      21.0  ...               1
# 555         0.486        0.767         0.375      21.0  ...               0
# ...           ...          ...           ...       ...  ...             ...
# 1873        0.485        0.769         0.413      33.0  ...               1
# 1887        0.419        0.667         0.333      23.0  ...               1
# 1904        0.455        0.684         0.333      28.0  ...               0
# 1909        0.409        0.697         0.297      22.0  ...               0
# 1923        0.524        0.750         0.512      28.0  ...               1
#
#         HOME_TEAM_NAME  VISITOR_TEAM_NAME  year_month  negative %_x  \
# 548          MiamiHeat      BostonCeltics     2022-05     13.760926
# 549      BostonCeltics          MiamiHeat     2022-05     13.760926
# 551          MiamiHeat      BostonCeltics     2022-05     13.760926
# 553      BostonCeltics          MiamiHeat     2022-05     13.760926
# 555      BostonCeltics          MiamiHeat     2022-05     13.760926
# ...                ...                ...         ...           ...
# 1873      AtlantaHawks          MiamiHeat     2021-10     13.760926
# 1887         MiamiHeat   CharlotteHornets     2021-10     13.760926
# 1904  San AntonioSpurs          MiamiHeat     2021-10     13.760926
# 1909    HoustonRockets          MiamiHeat     2021-10     13.760926
# 1923         MiamiHeat       AtlantaHawks     2021-10     13.760926
#
#       neutral %_x  positive %_x  negative %_y  neutral %_y positive %_y
# 548     53.310051     32.929024      13.85407    53.055657    33.090273
# 549     53.310051     32.929024      13.85407    53.055657    33.090273
# 551     53.310051     32.929024      13.85407    53.055657    33.090273
# 553     53.310051     32.929024      13.85407    53.055657    33.090273
# 555     53.310051     32.929024      13.85407    53.055657    33.090273
# ...           ...           ...           ...          ...          ...
# 1873    53.310051     32.929024      13.85407    53.055657    33.090273
# 1887    53.310051     32.929024      13.85407    53.055657    33.090273
# 1904    53.310051     32.929024      13.85407    53.055657    33.090273
# 1909    53.310051     32.929024      13.85407    53.055657    33.090273
# 1923    53.310051     32.929024      13.85407    53.055657    33.090273
#
# [106 rows x 28 columns]

# %%
games.loc[((games["HOME_TEAM_ID"] == 1610612748) | (games["VISITOR_TEAM_ID"] == 1610612748))]['SEASON'].value_counts()
# Out:
# 2012    113
# 2005    112
# 2013    110
# 2010    109
# 2021    106
# 2015    104
# 2019    102
# 2003    102
# 2004    100
# 2008     96
# 2009     94
# 2017     93
# 2006     93
# 2011     91
# 2014     90
# 2016     90
# 2007     89
# 2018     88
# 2020     79
# 2022     37
# Name: SEASON, dtype: int64

# %% [markdown]
# Dataset includes playoff games!

# %%
#aggregation
YEARS = [i for i in range(2003,2023)]

# %%
def data_transformation(games,TEAM_ID,YEAR):
  df = games.loc[((games["HOME_TEAM_ID"] == TEAM_ID)
  | (games["VISITOR_TEAM_ID"] == TEAM_ID))].loc[games['SEASON'] == YEAR]
  df.sort_values(by=['GAME_DATE_EST'],ascending=True,inplace=True)
  df = df[['HOME_TEAM_ID', 'VISITOR_TEAM_ID',
                                              'PTS_home', 'FG_PCT_home',
                                              'FT_PCT_home', 'FG3_PCT_home',
                                              'AST_home', 'REB_home',
                                              'TEAM_ID_away', 'PTS_away',
                                              'FG_PCT_away', 'FT_PCT_away',
                                              'FG3_PCT_away', 'AST_away',
                                              'REB_away', 'HOME_TEAM_WINS']]

  df['OTHER_TEAM_ID'] = np.where(df['HOME_TEAM_ID'] == TEAM_ID,
                                df['VISITOR_TEAM_ID'], df['HOME_TEAM_ID'])
  df['WIN'] = np.where(
      (df['HOME_TEAM_ID'] == TEAM_ID) & (df['HOME_TEAM_WINS'] == 1) |
      (df['HOME_TEAM_ID'] != TEAM_ID) & (df['HOME_TEAM_WINS'] == 0), 1, 0
  )
  # Identify columns with 'home' and 'away' suffixes
  home_columns = df.columns[df.columns.str.endswith('_home')]
  away_columns = df.columns[df.columns.str.endswith('_away')]
  # Create new columns with 'current' suffixes based on conditions
  df['PTS_current'] = np.where(df['HOME_TEAM_ID'] == TEAM_ID,
                              df['PTS_home'], df['PTS_away'])
  df['FG_PCT_current'] = np.where(df['HOME_TEAM_ID'] == TEAM_ID,
                                  df['FG_PCT_home'], df['FG_PCT_away'])
  df['FT_PCT_current'] = np.where(df['HOME_TEAM_ID'] == TEAM_ID,
                                  df['FT_PCT_home'], df['FT_PCT_away'])
  df['FG3_PCT_current'] = np.where(df['HOME_TEAM_ID'] == TEAM_ID,
                                  df['FG3_PCT_home'], df['FG3_PCT_away'])
  df['AST_current'] = np.where(df['HOME_TEAM_ID'] == TEAM_ID,
                              df['AST_home'], df['AST_away'])
  df['REB_current'] = np.where(df['HOME_TEAM_ID'] == TEAM_ID,
                              df['REB_home'], df['REB_away'])
  df['PTS_opposing'] = np.where(df['HOME_TEAM_ID'] != TEAM_ID,
                                df['PTS_home'], df['PTS_away'])
  df['FG_PCT_opposing'] = np.where(df['HOME_TEAM_ID'] != TEAM_ID,
                                  df['FG_PCT_home'], df['FG_PCT_away'])
  df['FT_PCT_opposing'] = np.where(df['HOME_TEAM_ID'] != TEAM_ID,
                                  df['FT_PCT_home'], df['FT_PCT_away'])
  df['FG3_PCT_opposing'] = np.where(df['HOME_TEAM_ID'] != TEAM_ID,
                                    df['FG3_PCT_home'], df['FG3_PCT_away'])
  df['AST_opposing'] = np.where(df['HOME_TEAM_ID'] != TEAM_ID,
                                df['AST_home'], df['AST_away'])
  df['REB_opposing'] = np.where(df['HOME_TEAM_ID'] != TEAM_ID,
                                df['REB_home'], df['REB_away'])

  df = df.drop(home_columns, axis=1)
  df = df.drop(away_columns, axis=1)
  df.drop(['HOME_TEAM_ID', 'VISITOR_TEAM_ID','HOME_TEAM_WINS'],
          axis=1,inplace=True)
  return df

# %%
TEAM_IDS = list(teams['TEAM_ID'].unique())
dfs = [data_transformation(games,combo[0],combo[1])for combo in product(TEAM_IDS,YEARS)]
# Out:
# <ipython-input-25-8fa89c6538c6>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sort_values(by=['GAME_DATE_EST'],ascending=True,inplace=True)

# %%
# df.shape

# %% [markdown]
# ## Data Modelling

# %% [markdown]
# For singular team and year (heat, 2021)

# %%
TEAM_ID = 1610612748
YEAR = 2020

# %%
df = data_transformation(games,TEAM_ID,YEAR)

# %%
# games.loc[((games["HOME_TEAM_ID"] == TEAM_ID)
#   | (games["VISITOR_TEAM_ID"] == TEAM_ID))].loc[games['SEASON'] == YEAR].head(10)

# %%
# df.head(10)

# %%
# Feature columns
feature_columns = ['PTS_current', 'FG_PCT_current', 'FT_PCT_current',
                   'FG3_PCT_current', 'AST_current', 'REB_current',
                   'PTS_opposing', 'FG_PCT_opposing', 'FT_PCT_opposing',
                   'FG3_PCT_opposing', 'AST_opposing', 'REB_opposing']

# Target column
target_column = 'WIN'

# Function to create sequences
def create_sequences(data, sequence_length):
    sequences = []
    targets = []

    for i in range(len(data) - sequence_length):
        seq = data.iloc[i:i+sequence_length][feature_columns].values
        label = data.iloc[i+sequence_length][target_column]
        sequences.append(seq)
        targets.append(label)

    return np.array(sequences), np.array(targets)

# Choose sequence length
sequence_length = 10

# Create sequences and targets
sequences, targets = create_sequences(df, sequence_length)
print(sequences.shape)
print(targets.shape)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(sequences, targets, test_size=0.2, random_state=6868)

# Standardize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train.reshape(-1, X_train.shape[-1])).reshape(X_train.shape)
X_test = scaler.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)
# Out:
# (69, 10, 12)
# (69,)

# %%
# Build the LSTM model
model = Sequential()
model.add(LSTM(128, input_shape=(sequence_length, len(feature_columns)), activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
print(model.summary())
# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=128, validation_data=(X_test, y_test))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               72192
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 72321 (282.50 KB)
# Trainable params: 72321 (282.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.6975 - accuracy: 0.4364 - val_loss: 0.6888 - val_accuracy: 0.4286
# Epoch 2/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.6889 - accuracy: 0.5636 - val_loss: 0.6917 - val_accuracy: 0.5000
# Epoch 3/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.6819 - accuracy: 0.6182 - val_loss: 0.6951 - val_accuracy: 0.5714
# Epoch 4/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.6758 - accuracy: 0.6000 - val_loss: 0.6984 - val_accuracy: 0.5000
# Epoch 5/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.6701 - accuracy: 0.5818 - val_loss: 0.7014 - val_accuracy: 0.5000
# Epoch 6/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.6646 - accuracy: 0.6000 - val_loss: 0.7039 - val_accuracy: 0.5000
# Epoch 7/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.6590 - accuracy: 0.6182 - val_loss: 0.7057 - val_accuracy: 0.5000
# Epoch 8/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.6533 - accuracy: 0.6182 - val_loss: 0.7070 - val_accuracy: 0.5000
# Epoch 9/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6472 - accuracy: 0.6182 - val_loss: 0.7080 - val_accuracy: 0.4286
# Epoch 10/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.6408 - accuracy: 0.6727 - val_loss: 0.7086 - val_accuracy: 0.4286
# Epoch 11/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.6340 - accuracy: 0.6545 - val_loss: 0.7090 - val_accuracy: 0.4286
# Epoch 12/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.6269 - accuracy: 0.6727 - val_loss: 0.7096 - val_accuracy: 0.5000
# Epoch 13/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.6193 - accuracy: 0.6545 - val_loss: 0.7107 - val_accuracy: 0.5714
# Epoch 14/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.6113 - accuracy: 0.6909 - val_loss: 0.7126 - val_accuracy: 0.5714
# Epoch 15/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.6027 - accuracy: 0.7273 - val_loss: 0.7161 - val_accuracy: 0.5000
# Epoch 16/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5934 - accuracy: 0.7455 - val_loss: 0.7213 - val_accuracy: 0.5000
# Epoch 17/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.5832 - accuracy: 0.7455 - val_loss: 0.7283 - val_accuracy: 0.5000
# Epoch 18/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.5723 - accuracy: 0.7091 - val_loss: 0.7377 - val_accuracy: 0.5000
# Epoch 19/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5611 - accuracy: 0.7091 - val_loss: 0.7488 - val_accuracy: 0.5714
# Epoch 20/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.5499 - accuracy: 0.7273 - val_loss: 0.7588 - val_accuracy: 0.5714
# Epoch 21/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.5396 - accuracy: 0.7455 - val_loss: 0.7661 - val_accuracy: 0.5714
# Epoch 22/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.5296 - accuracy: 0.7636 - val_loss: 0.7748 - val_accuracy: 0.6429
# Epoch 23/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.5207 - accuracy: 0.7818 - val_loss: 0.7823 - val_accuracy: 0.5714
# Epoch 24/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.5097 - accuracy: 0.7636 - val_loss: 0.7840 - val_accuracy: 0.5714
# Epoch 25/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.4948 - accuracy: 0.7818 - val_loss: 0.7848 - val_accuracy: 0.5000
# Epoch 26/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.4776 - accuracy: 0.7818 - val_loss: 0.7941 - val_accuracy: 0.5000
# Epoch 27/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.4612 - accuracy: 0.7636 - val_loss: 0.8014 - val_accuracy: 0.5000
# Epoch 28/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.4471 - accuracy: 0.8000 - val_loss: 0.8183 - val_accuracy: 0.5714
# Epoch 29/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.4409 - accuracy: 0.7818 - val_loss: 0.8178 - val_accuracy: 0.6429
# Epoch 30/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.4291 - accuracy: 0.7818 - val_loss: 0.8008 - val_accuracy: 0.6429
# Epoch 31/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.4083 - accuracy: 0.8000 - val_loss: 0.7863 - val_accuracy: 0.5714
# Epoch 32/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3878 - accuracy: 0.8364 - val_loss: 0.7699 - val_accuracy: 0.5714
# Epoch 33/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3740 - accuracy: 0.8364 - val_loss: 0.8247 - val_accuracy: 0.5000
# Epoch 34/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.3787 - accuracy: 0.8000 - val_loss: 0.7646 - val_accuracy: 0.7143
# Epoch 35/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.3617 - accuracy: 0.8364 - val_loss: 0.7783 - val_accuracy: 0.7143
# Epoch 36/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.3340 - accuracy: 0.8727 - val_loss: 0.8259 - val_accuracy: 0.5000
# Epoch 37/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.3299 - accuracy: 0.8727 - val_loss: 0.8168 - val_accuracy: 0.7143
# Epoch 38/100
# 1/1 [==============================] - 0s 70ms/step - loss: 0.3074 - accuracy: 0.8727 - val_loss: 0.8220 - val_accuracy: 0.7143
# Epoch 39/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3047 - accuracy: 0.8545 - val_loss: 0.8484 - val_accuracy: 0.7143
# Epoch 40/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.2836 - accuracy: 0.8545 - val_loss: 0.9105 - val_accuracy: 0.5714
# Epoch 41/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.2807 - accuracy: 0.8909 - val_loss: 0.8708 - val_accuracy: 0.7143
# Epoch 42/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.2563 - accuracy: 0.8727 - val_loss: 0.8762 - val_accuracy: 0.7143
# Epoch 43/100
# 1/1 [==============================] - 0s 79ms/step - loss: 0.2488 - accuracy: 0.8727 - val_loss: 0.9091 - val_accuracy: 0.6429
# Epoch 44/100
# 1/1 [==============================] - 0s 85ms/step - loss: 0.2301 - accuracy: 0.9091 - val_loss: 0.9360 - val_accuracy: 0.6429
# Epoch 45/100
# 1/1 [==============================] - 0s 73ms/step - loss: 0.2211 - accuracy: 0.8909 - val_loss: 0.9412 - val_accuracy: 0.7143
# Epoch 46/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.2121 - accuracy: 0.9091 - val_loss: 1.0031 - val_accuracy: 0.5714
# Epoch 47/100
# 1/1 [==============================] - 0s 66ms/step - loss: 0.1991 - accuracy: 0.9455 - val_loss: 1.0097 - val_accuracy: 0.6429
# Epoch 48/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.1807 - accuracy: 0.9455 - val_loss: 1.0111 - val_accuracy: 0.7143
# Epoch 49/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1794 - accuracy: 0.9455 - val_loss: 0.9845 - val_accuracy: 0.7143
# Epoch 50/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1592 - accuracy: 0.9455 - val_loss: 1.0140 - val_accuracy: 0.5714
# Epoch 51/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.1584 - accuracy: 0.9455 - val_loss: 0.9337 - val_accuracy: 0.7143
# Epoch 52/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1416 - accuracy: 0.9636 - val_loss: 0.9505 - val_accuracy: 0.7143
# Epoch 53/100
# 1/1 [==============================] - 0s 91ms/step - loss: 0.1336 - accuracy: 0.9636 - val_loss: 0.9777 - val_accuracy: 0.6429
# Epoch 54/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1232 - accuracy: 0.9455 - val_loss: 1.0062 - val_accuracy: 0.6429
# Epoch 55/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.1102 - accuracy: 0.9636 - val_loss: 1.1101 - val_accuracy: 0.5714
# Epoch 56/100
# 1/1 [==============================] - 0s 75ms/step - loss: 0.1291 - accuracy: 0.9455 - val_loss: 1.4472 - val_accuracy: 0.5714
# Epoch 57/100
# 1/1 [==============================] - 0s 70ms/step - loss: 0.6776 - accuracy: 0.8000 - val_loss: 1.3669 - val_accuracy: 0.7143
# Epoch 58/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.1769 - accuracy: 0.9091 - val_loss: 2.2456 - val_accuracy: 0.7143
# Epoch 59/100
# 1/1 [==============================] - 0s 72ms/step - loss: 0.9384 - accuracy: 0.7636 - val_loss: 1.0640 - val_accuracy: 0.6429
# Epoch 60/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2138 - accuracy: 0.8909 - val_loss: 0.7602 - val_accuracy: 0.6429
# Epoch 61/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.1388 - accuracy: 0.9273 - val_loss: 1.2049 - val_accuracy: 0.7143
# Epoch 62/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.4513 - accuracy: 0.7818 - val_loss: 1.1897 - val_accuracy: 0.7143
# Epoch 63/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.4699 - accuracy: 0.7818 - val_loss: 0.8457 - val_accuracy: 0.7143
# Epoch 64/100
# 1/1 [==============================] - 0s 85ms/step - loss: 0.2441 - accuracy: 0.8909 - val_loss: 0.6569 - val_accuracy: 0.6429
# Epoch 65/100
# 1/1 [==============================] - 0s 66ms/step - loss: 0.1602 - accuracy: 0.9455 - val_loss: 0.6128 - val_accuracy: 0.7143
# Epoch 66/100
# 1/1 [==============================] - 0s 80ms/step - loss: 0.1518 - accuracy: 0.9636 - val_loss: 0.6292 - val_accuracy: 0.7143
# Epoch 67/100
# 1/1 [==============================] - 0s 92ms/step - loss: 0.2010 - accuracy: 0.9091 - val_loss: 0.6732 - val_accuracy: 0.6429
# Epoch 68/100
# 1/1 [==============================] - 0s 88ms/step - loss: 0.2512 - accuracy: 0.9091 - val_loss: 0.7084 - val_accuracy: 0.6429
# Epoch 69/100
# 1/1 [==============================] - 0s 78ms/step - loss: 0.2644 - accuracy: 0.8909 - val_loss: 0.7211 - val_accuracy: 0.6429
# Epoch 70/100
# 1/1 [==============================] - 0s 85ms/step - loss: 0.2381 - accuracy: 0.8909 - val_loss: 0.7195 - val_accuracy: 0.6429
# Epoch 71/100
# 1/1 [==============================] - 0s 83ms/step - loss: 0.1929 - accuracy: 0.9273 - val_loss: 0.7195 - val_accuracy: 0.7143
# Epoch 72/100
# 1/1 [==============================] - 0s 81ms/step - loss: 0.1676 - accuracy: 0.9636 - val_loss: 0.7282 - val_accuracy: 0.7143
# Epoch 73/100
# 1/1 [==============================] - 0s 80ms/step - loss: 0.1565 - accuracy: 0.9636 - val_loss: 0.7468 - val_accuracy: 0.6429
# Epoch 74/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1531 - accuracy: 0.9455 - val_loss: 0.7737 - val_accuracy: 0.6429
# Epoch 75/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.1570 - accuracy: 0.9455 - val_loss: 0.8035 - val_accuracy: 0.7143
# Epoch 76/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.1679 - accuracy: 0.9455 - val_loss: 0.8274 - val_accuracy: 0.7143
# Epoch 77/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.1804 - accuracy: 0.9455 - val_loss: 0.8360 - val_accuracy: 0.7143
# Epoch 78/100
# 1/1 [==============================] - 0s 77ms/step - loss: 0.1798 - accuracy: 0.9273 - val_loss: 0.8285 - val_accuracy: 0.7143
# Epoch 79/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.1642 - accuracy: 0.9455 - val_loss: 0.8135 - val_accuracy: 0.6429
# Epoch 80/100
# 1/1 [==============================] - 0s 85ms/step - loss: 0.1477 - accuracy: 0.9636 - val_loss: 0.7993 - val_accuracy: 0.6429
# Epoch 81/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.1377 - accuracy: 0.9636 - val_loss: 0.7903 - val_accuracy: 0.6429
# Epoch 82/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.1335 - accuracy: 0.9636 - val_loss: 0.7865 - val_accuracy: 0.7143
# Epoch 83/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.1328 - accuracy: 0.9636 - val_loss: 0.7861 - val_accuracy: 0.7143
# Epoch 84/100
# 1/1 [==============================] - 0s 71ms/step - loss: 0.1336 - accuracy: 0.9818 - val_loss: 0.7869 - val_accuracy: 0.7143
# Epoch 85/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.1338 - accuracy: 0.9636 - val_loss: 0.7869 - val_accuracy: 0.7143
# Epoch 86/100
# 1/1 [==============================] - 0s 79ms/step - loss: 0.1317 - accuracy: 0.9636 - val_loss: 0.7855 - val_accuracy: 0.7143
# Epoch 87/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1271 - accuracy: 0.9636 - val_loss: 0.7828 - val_accuracy: 0.7143
# Epoch 88/100
# 1/1 [==============================] - 0s 79ms/step - loss: 0.1206 - accuracy: 0.9636 - val_loss: 0.7809 - val_accuracy: 0.7143
# Epoch 89/100
# 1/1 [==============================] - 0s 81ms/step - loss: 0.1136 - accuracy: 0.9818 - val_loss: 0.7815 - val_accuracy: 0.6429
# Epoch 90/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.1073 - accuracy: 0.9636 - val_loss: 0.7856 - val_accuracy: 0.6429
# Epoch 91/100
# 1/1 [==============================] - 0s 78ms/step - loss: 0.1025 - accuracy: 0.9636 - val_loss: 0.7933 - val_accuracy: 0.6429
# Epoch 92/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0992 - accuracy: 0.9636 - val_loss: 0.8031 - val_accuracy: 0.6429
# Epoch 93/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0969 - accuracy: 0.9636 - val_loss: 0.8140 - val_accuracy: 0.6429
# Epoch 94/100
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0947 - accuracy: 0.9636 - val_loss: 0.8243 - val_accuracy: 0.7143
# Epoch 95/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0917 - accuracy: 0.9636 - val_loss: 0.8327 - val_accuracy: 0.6429
# Epoch 96/100
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0875 - accuracy: 0.9636 - val_loss: 0.8399 - val_accuracy: 0.6429
# Epoch 97/100
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0823 - accuracy: 0.9636 - val_loss: 0.8465 - val_accuracy: 0.6429
# Epoch 98/100
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0769 - accuracy: 0.9636 - val_loss: 0.8546 - val_accuracy: 0.6429
# Epoch 99/100
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0719 - accuracy: 0.9818 - val_loss: 0.8650 - val_accuracy: 0.6429
# Epoch 100/100
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0677 - accuracy: 0.9818 - val_loss: 0.8781 - val_accuracy: 0.6429

# %%
# Save accuracy and loss values
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']

# Plot epochs vs loss
plt.plot(training_loss, label='Training Loss')
plt.plot(validation_loss, label='Validation Loss')
plt.title('Epochs vs Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot epochs vs accuracy
plt.plot(training_accuracy, label='Training Accuracy')
plt.plot(validation_accuracy, label='Validation Accuracy')
plt.title('Epochs vs Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# 1/1 [==============================] - 0s 28ms/step - loss: 0.8781 - accuracy: 0.6429
# Test Loss: 0.8781, Test Accuracy: 0.6429
